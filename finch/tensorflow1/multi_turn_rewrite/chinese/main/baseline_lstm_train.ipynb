# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/multi_turn_rewrite/chinese/main')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %tensorflow_version 1.x
# !pip install texar
# Out:
# Requirement already satisfied: texar in /usr/local/lib/python3.6/dist-packages (0.2.4)
# Requirement already satisfied: numpy<1.17.0 in /usr/local/lib/python3.6/dist-packages (from texar) (1.16.5)
# Requirement already satisfied: pathlib>=1.0 in /usr/local/lib/python3.6/dist-packages (from texar) (1.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from texar) (19.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from texar) (2.21.0)
# Requirement already satisfied: sentencepiece>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from texar) (0.1.83)
# Requirement already satisfied: regex>=2018.01.10 in /usr/local/lib/python3.6/dist-packages (from texar) (2019.11.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from texar) (3.13)
# Requirement already satisfied: funcsigs>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from texar) (1.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->texar) (1.12.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->texar) (2.4.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->texar) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->texar) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->texar) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->texar) (2.8)

# %%
import tensorflow as tf
import texar.tf as tx

import numpy as np
import pprint
import logging

from pathlib import Path

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.15.0
# GPU Enabled: True

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip('\n')
      word2idx[line] = i
  return word2idx

# %%
def align_pad(li):
  max_len = max([len(sent) for sent in li])
  for sent in li:
    if len(sent) < max_len:
      sent += [0] * (max_len - len(sent))

# %%
def data_generator(f_path, params):
  with open(f_path) as f:
    for line in f:
      line = line.rstrip()
      h1, h2, q, a = line.split('\t')
      char2idx_fn = lambda x: [params['char2idx'].get(c, len(params['char2idx'])) for c in list(x)]
      h1, h2, q, a = char2idx_fn(h1), char2idx_fn(h2), char2idx_fn(q), char2idx_fn(a)
      align_pad([h1, h2])
      a_in = [1] + a
      a_out = a + [2]
      nested = ({'history': [h1, h2], 'query': q}, (a_in, a_out))
      yield nested

# %%
def dataset(is_training, params):
  _shapes = ({'history':[None, None], 'query':[None]}, ([None], [None]))
  _types = ({'history':tf.int32, 'query': tf.int32}, (tf.int32, tf.int32))
  _pads = ({'history':0, 'query':0}, (0, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
def clip_grads(loss):
    variables = tf.trainable_variables()
    pprint.pprint(variables)
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    def cell_fn():
        cell = tf.nn.rnn_cell.LSTMCell(params['hidden_units'],
                                       initializer=tf.orthogonal_initializer())
        return cell
    if params['dec_layers'] > 1:
      cells = []
      for i in range(params['dec_layers']):
        if i == params['dec_layers'] - 1:
          cells.append(cell_fn())
        else:
          cells.append(tf.nn.rnn_cell.ResidualWrapper(cell_fn(), residual_fn=lambda i,o: tf.concat((i,o), -1)))
      return tf.nn.rnn_cell.MultiRNNCell(cells)
    else:
      return cell_fn()

  
def dec_cell(enc_out, enc_seq_len):
    query, history = enc_out
    query_len, history_len = enc_seq_len

    attn1 = tf.contrib.seq2seq.LuongAttention(
        num_units = params['hidden_units'],
        memory = query,
        memory_sequence_length = query_len)
    
    attn2 = tf.contrib.seq2seq.BahdanauAttention(
        num_units = params['hidden_units'],
        memory = history,
        memory_sequence_length = history_len)
    
    return tf.contrib.seq2seq.AttentionWrapper(
        cell = rnn_cell(),
        attention_mechanism = [attn1, attn2],
        attention_layer_size = [params['hidden_units']//2, params['hidden_units']//2])
    

class TiedDense(tf.layers.Layer):
  def __init__(self, tied_embed, out_dim):
    super().__init__()
    self.tied_embed = tied_embed
    self.out_dim = out_dim
  
  def build(self, input_shape):
    self.bias = self.add_weight(name='bias',
                                shape=[self.out_dim],
                                trainable=True)
    super().build(input_shape)
  
  def call(self, inputs):
    x = tf.matmul(inputs, self.tied_embed, transpose_b=True)
    x = tf.nn.bias_add(x, self.bias)
    return x
  
  def compute_output_shape(self, input_shape):
    return input_shape[:-1].concatenate(self.out_dim)

# %%
def bilstm_encode(lstm_cell_fw, lstm_cell_bw, x, words_len):
  t = tf.transpose(x, perm=[1, 0, 2])  # time-major
  o_fw, s_fw = lstm_cell_fw(t, dtype=tf.float32, sequence_length=words_len)
  o_bw, s_bw = lstm_cell_bw(t, dtype=tf.float32, sequence_length=words_len)
  enc_out = tf.concat((o_fw, o_bw), axis=-1)
  enc_out = tf.transpose(enc_out, perm=[1, 0, 2])
  enc_state = tf.concat((s_fw.h, s_bw.h), axis=-1)
  return enc_out, enc_state


def teach_forcing(labels, embedding, enc_out, enc_state, words_len, batch_sz, params, is_training, output_proj):
  dec_inputs, dec_outputs = labels
  dec_seq_len = tf.count_nonzero(dec_inputs, 1, dtype=tf.int32)
  dec_inputs = tf.nn.embedding_lookup(embedding, dec_inputs)
  dec_inputs = tf.layers.dropout(dec_inputs, params['dropout_rate'], training=is_training)
  cell = dec_cell(enc_out, words_len)
  
  init_state = cell.zero_state(batch_sz, tf.float32).clone(
      cell_state=enc_state)
  
  helper = tf.contrib.seq2seq.TrainingHelper(
      inputs = dec_inputs,
      sequence_length = dec_seq_len,)
  decoder = tf.contrib.seq2seq.BasicDecoder(
      cell = cell,
      helper = helper,
      initial_state = init_state,
      output_layer = output_proj)
  decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
      decoder = decoder,
      maximum_iterations = tf.reduce_max(dec_seq_len))
  
  return decoder_output.rnn_output


def beam_search(embedding, enc_out, enc_state, words_len, batch_sz, params, output_proj):
  enc_out_t = [tf.contrib.seq2seq.tile_batch(e, params['beam_width']) for e in enc_out]
  enc_state_t = tf.contrib.seq2seq.tile_batch(enc_state, params['beam_width'])
  enc_seq_len_t = []
  for l in words_len:
    if l is not None:
      enc_seq_len_t.append(tf.contrib.seq2seq.tile_batch(l, params['beam_width']))
    else:
      enc_seq_len_t.append(l)
  
  cell = dec_cell(enc_out_t, enc_seq_len_t)
  
  init_state = cell.zero_state(batch_sz*params['beam_width'], tf.float32).clone(
      cell_state=enc_state_t)
  
  decoder = tf.contrib.seq2seq.BeamSearchDecoder(
      cell = cell,
      embedding = embedding,
      start_tokens = tf.tile(tf.constant([1], tf.int32), [batch_sz]),
      end_token = 2,
      initial_state = init_state,
      beam_width = params['beam_width'],
      output_layer = output_proj,
      length_penalty_weight = params['length_penalty'],
      coverage_penalty_weight = params['coverage_penalty'],)
  decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
      decoder = decoder,
      maximum_iterations = params['max_len'],)
  
  return decoder_output.predicted_ids[:, :, 0]

# %%
def dynamic_memory_update(query, history):
  proj_1 = tf.layers.Dense(params['hidden_units'], tf.tanh, name='attn_proj_1')
  proj_2 = tf.layers.Dense(1, name='attn_proj_2')
  memory_proj = tf.layers.Dense(params['hidden_units'], params['activation'], name='memory_proj')

  memory = query
  for i in range(params['num_hops']):
      episode = gen_episode(memory,
                            query,
                            history,
                            proj_1,
                            proj_2,)
      memory = memory_proj(tf.concat([memory, episode, query], 1))

  lstm_memory = tf.nn.rnn_cell.LSTMStateTuple(c=memory, h=memory)
  if params['dec_layers'] > 1:
    lstm_memory = tuple(params['dec_layers'] * [lstm_memory])
  
  return lstm_memory


def gen_episode(memory, q_vec, fact_vecs, proj_1, proj_2):
  def gen_attn(fact_vec):
      features = [fact_vec * q_vec,
                  fact_vec * memory,
                  tf.abs(fact_vec - q_vec),
                  tf.abs(fact_vec - memory)]
      feature_vec = tf.concat(features, 1)
      attention = proj_1(feature_vec)
      attention = proj_2(attention)
      return tf.squeeze(attention, 1)
  
  attns = tf.map_fn(gen_attn, tf.transpose(fact_vecs, [1,0,2]))
  attns = tf.transpose(attns)                                      # (B, n_fact)
  attns = tf.nn.softmax(attns)                                     # (B, n_fact)
  attns = tf.expand_dims(attns, -1)                                # (B, n_fact, 1)
  episode = tf.matmul(fact_vecs, attns, transpose_a=True)
  episode = tf.squeeze(episode, -1)

  return episode

# %%
def forward(features, labels, mode):
    history = features['history']
    query = features['query']
    query_valid_len = tf.count_nonzero(query, 1, dtype=tf.int32)
    
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    batch_sz = tf.shape(query)[0]

    num_history = tf.shape(history)[1]
    history_len = tf.shape(history)[2]
    history = tf.reshape(history, (num_history*batch_sz, history_len))
    history_valid_len = tf.count_nonzero(history, 1, dtype=tf.int32)
    
    
    with tf.variable_scope('Embedding'):
        embedding = tf.Variable(np.load('../vocab/char.npy'),
                                dtype=tf.float32,
                                name='fasttext_vectors')
        def embed_fn(x):
          x = tf.nn.embedding_lookup(embedding, x)
          x = tf.layers.dropout(x, params['dropout_rate'], training=is_training)
          return x
        query = embed_fn(query)
        history = embed_fn(history)
    
    
    with tf.variable_scope('Encoder'):
        lstm_cell_fw = tf.contrib.rnn.LSTMBlockFusedCell(params['hidden_units'])
        lstm_cell_bw = tf.contrib.rnn.LSTMBlockFusedCell(params['hidden_units'])
        lstm_cell_bw = tf.contrib.rnn.TimeReversedFusedRNN(lstm_cell_bw)

        query_out, query_state = bilstm_encode(lstm_cell_fw, lstm_cell_bw, query, query_valid_len)
        history_out, history_state = bilstm_encode(lstm_cell_fw, lstm_cell_bw, history, history_valid_len)

        feat_proj = tf.layers.Dense(params['hidden_units'], params['activation'], name='feature_projection')
        def feat_engine(out, state):
          return feat_proj(tf.concat((tf.reduce_max(out, 1), state), -1))
        query_feat = feat_engine(query_out, query_state)
        history_feat = tf.reshape(feat_engine(history_out, history_state), (batch_sz, num_history, params['hidden_units']))


    with tf.variable_scope('Dynamic_Memory'): 
      dynamic_memory = dynamic_memory_update(query_feat, history_feat)
      query_memory = query_out
      history_memory = tf.reshape(history_out, (batch_sz, num_history*history_len, 2*params['hidden_units']))
      static_memory = [query_memory, history_memory]
      memory_len = [query_valid_len, None]


    with tf.variable_scope('Decoder'):
        output_proj = TiedDense(embedding, len(params['char2idx'])+1)
        
        if is_training or (mode == tf.estimator.ModeKeys.EVAL):
            return teach_forcing(labels, embedding, static_memory, dynamic_memory, memory_len, batch_sz, params, is_training, output_proj)
        else:
            return beam_search(embedding, static_memory, dynamic_memory, memory_len, batch_sz, params, output_proj)

# %%
def model_fn(features, labels, mode, params):
    logits_or_ids = forward(features, labels, mode)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
    
    dec_inputs, dec_outputs = labels
    if (params['label_smoothing'] <= .0) or (mode == tf.estimator.ModeKeys.EVAL):
      loss_op = tf.contrib.seq2seq.sequence_loss(logits = logits_or_ids,
                                                 targets = dec_outputs,
                                                 weights = tf.to_float(tf.sign(dec_outputs)))
    else:
      loss_op = tf.losses.softmax_cross_entropy(onehot_labels = tf.one_hot(dec_outputs, len(params['char2idx'])+1),
                                                logits = logits_or_ids,
                                                weights = tf.to_float(tf.sign(dec_outputs)),
                                                label_smoothing = params['label_smoothing'],)
      
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step=tf.train.get_or_create_global_step()
        
        decay_lr = tf.train.exponential_decay(
            params['lr'], global_step, 1000, .99)
        
        train_op = tf.train.AdamOptimizer(decay_lr).apply_gradients(
            clip_grads(loss_op), global_step=global_step)
        
        hook = tf.train.LoggingTensorHook({'lr': decay_lr}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[hook],)
      
    if mode == tf.estimator.ModeKeys.EVAL:
      return tf.estimator.EstimatorSpec(mode=mode, loss=loss_op)

# %%
def minimal_test(estimator):
  test_str = '房子好贵|房价涨房租跟着涨|买不起'
  h1, h2, q = test_str.split('|')
  char2idx_fn = lambda x: [params['char2idx'].get(c, len(params['char2idx'])) for c in list(x)]
  h1, h2, q = char2idx_fn(h1), char2idx_fn(h2), char2idx_fn(q)
  align_pad([h1, h2])
  predicted = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
    x = {'history':np.reshape([h1, h2], (1, 2, len(h1))),
         'query':np.reshape(q, (1, len(q)))},
         shuffle = False)))[0]
  predicted = ''.join([params['idx2char'].get(idx, '<unk>') for idx in predicted if (idx != 0 and idx != 2)])
  print('-'*12)
  print('minimal test')
  print('Q:', test_str)
  print('A:', predicted)
  print('-'*12)

# %%
def is_descending(history: list):
  history = history[-(params['num_patience']+1):]
  for i in range(1, len(history)):
    if history[i-1] <= history[i]:
      return False
  return True

# %%
params = {
    'model_dir': '../model/baseline_lstm',
    'log_path': '../log/baseline_lstm.txt',
    'train_path': '../data/train.txt',
    'test_path': '../data/test.txt',
    'vocab_path': '../vocab/char.txt',
    'max_len': 30,
    'activation': tf.nn.relu,
    'dropout_rate': .2,
    'hidden_units': 300,
    'dec_layers': 1,
    'num_hops': 3,
    'beam_width': 5,
    'length_penalty': .0,
    'coverage_penalty': .0,
    'lr': 4e-4,
    'clip_norm': .1,
    'label_smoothing': .2,
    'buffer_size': 20000,
    'batch_size': 32,
    'num_patience': 5,
}

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['idx2char'] = {idx: char for char, idx in params['char2idx'].items()}

# %%
# Create directory if not exist
Path(os.path.dirname(params['log_path'])).mkdir(exist_ok=True)
Path(params['model_dir']).mkdir(exist_ok=True, parents=True)

# Logging
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)
fh = logging.FileHandler(params['log_path'])
logger.addHandler(fh)

# Create an estimator
estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  model_dir=params['model_dir'],
  config=tf.estimator.RunConfig(
    save_checkpoints_steps=params['buffer_size']//params['batch_size'], keep_checkpoint_max=1),
  params=params)

best_bleu = 0.
history_bleu = []
tf.enable_eager_execution()

while True:
  estimator.train(input_fn=lambda: dataset(is_training=True, params=params))

  minimal_test(estimator)

  loss = estimator.evaluate(input_fn=lambda: dataset(is_training=False, params=params))['loss']
  ppl = np.exp(loss)
  logger.info("Perplexity: {:.3f}".format(ppl))

  # BLEU
  labels = [label for _, (_, label) in dataset(is_training=False, params=params)]
  labels = [j for i in labels for j in i.numpy()]
  labels = [[params['idx2char'].get(idx, '<unk>') for idx in arr if (idx!=0 and idx!=2)] for arr in labels]

  preds = list(estimator.predict(input_fn=lambda: dataset(is_training=False, params=params)))
  assert len(labels) == len(preds)
  preds = [[params['idx2char'].get(idx, '<unk>') for idx in arr if (idx!=0 and idx!=2)] for arr in preds]

  em = [np.all(p == l) for p, l in zip(preds, labels)]
  em = np.asarray(em).mean()

  bleu, bleu_1, bleu_2, bleu_3, bleu_4 = tx.evals.corpus_bleu_moses(list_of_references=[[l] for l in labels], hypotheses=preds, return_all=True)
  logger.info("BLEU: {:.3f}, BELU-1: {:.3f}, BLEU-2: {:.3f}, BLEU-4: {:.3f}, EM: {:.3f}".format(bleu, bleu_1, bleu_2, bleu_4, em))
  history_bleu.append(bleu)

  if bleu > best_bleu:
    best_bleu = bleu
  logger.info("Best BLEU: {:.3f}".format(best_bleu))

  if len(history_bleu) > params['num_patience'] and is_descending(history_bleu):
    logger.info("BLEU not improved over {} epochs, Early Stop".format(params['num_patience']))
    break
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '../model/baseline_lstm', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 625, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcc90aaccc0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/deprecation.py:507: calling count_nonzero (from tensorflow.python.ops.math_ops) with axis is deprecated and will be removed in a future version.
# Instructions for updating:
# reduction_indices is deprecated, use axis instead
# WARNING:tensorflow:From <ipython-input-11-6b206e9f19e3>:21: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:271: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/rnn/python/ops/lstm_ops.py:597: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From <ipython-input-8-0eb31f0b588f>:12: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/seq2seq/python/ops/attention_wrapper.py:2078: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From <ipython-input-12-aafb468fc0d9>:15: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 8.272096, step = 0
# INFO:tensorflow:lr = 0.0004
# INFO:tensorflow:global_step/sec: 3.97971
# INFO:tensorflow:loss = 6.3223433, step = 100 (25.130 sec)
# INFO:tensorflow:lr = 0.00039959815 (25.129 sec)
# INFO:tensorflow:global_step/sec: 4.45882
# INFO:tensorflow:loss = 5.916761, step = 200 (22.427 sec)
# INFO:tensorflow:lr = 0.00039919675 (22.426 sec)
# INFO:tensorflow:global_step/sec: 4.14026
# INFO:tensorflow:loss = 5.6697545, step = 300 (24.154 sec)
# INFO:tensorflow:lr = 0.00039879576 (24.149 sec)
# INFO:tensorflow:global_step/sec: 4.17824
# INFO:tensorflow:loss = 5.147065, step = 400 (23.940 sec)
# INFO:tensorflow:lr = 0.00039839515 (23.939 sec)
# INFO:tensorflow:global_step/sec: 4.20354
# INFO:tensorflow:loss = 4.91169, step = 500 (23.788 sec)
# INFO:tensorflow:lr = 0.00039799497 (23.788 sec)
# INFO:tensorflow:Saving checkpoints for 595 into ../model/baseline_lstm/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Loss for final step: 4.653014.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/seq2seq/python/ops/beam_search_decoder.py:971: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-595
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 买不去
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T05:54:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-595
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-05:54:34
# INFO:tensorflow:Saving dict for global step 595: global_step = 595, loss = 3.1679971
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 595: ../model/baseline_lstm/model.ckpt-595
# INFO:tensorflow:Perplexity: 23.760
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-595
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:BLEU: 21.530, BELU-1: 61.600, BLEU-2: 37.800, BLEU-4: 13.000, EM: 0.012
# INFO:tensorflow:Best BLEU: 21.530
# INFO:tensorflow:Calling model_fn.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-595
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 595 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 4.4183726, step = 595
# INFO:tensorflow:lr = 0.00039761513
# INFO:tensorflow:global_step/sec: 3.89657
# INFO:tensorflow:loss = 4.265689, step = 695 (25.672 sec)
# INFO:tensorflow:lr = 0.0003972157 (25.671 sec)
# INFO:tensorflow:global_step/sec: 4.19523
# INFO:tensorflow:loss = 3.9458458, step = 795 (23.831 sec)
# INFO:tensorflow:lr = 0.00039681673 (23.831 sec)
# INFO:tensorflow:global_step/sec: 4.29749
# INFO:tensorflow:loss = 3.6759183, step = 895 (23.276 sec)
# INFO:tensorflow:lr = 0.0003964181 (23.277 sec)
# INFO:tensorflow:global_step/sec: 4.39573
# INFO:tensorflow:loss = 3.6663299, step = 995 (22.748 sec)
# INFO:tensorflow:lr = 0.0003960199 (22.749 sec)
# INFO:tensorflow:global_step/sec: 4.04945
# INFO:tensorflow:loss = 3.783076, step = 1095 (24.694 sec)
# INFO:tensorflow:lr = 0.00039562205 (24.692 sec)
# INFO:tensorflow:Saving checkpoints for 1190 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.2676039.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-1190
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 买房房不起
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T05:57:27Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-1190
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-05:57:30
# INFO:tensorflow:Saving dict for global step 1190: global_step = 1190, loss = 1.60908
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1190: ../model/baseline_lstm/model.ckpt-1190
# INFO:tensorflow:Perplexity: 4.998
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-1190
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:BLEU: 55.080, BELU-1: 89.100, BLEU-2: 76.100, BLEU-4: 55.100, EM: 0.189
# INFO:tensorflow:Best BLEU: 55.080
# INFO:tensorflow:Calling model_fn.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-1190
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1190 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 3.451157, step = 1190
# INFO:tensorflow:lr = 0.0003952445
# INFO:tensorflow:global_step/sec: 4.0012
# INFO:tensorflow:loss = 3.4009888, step = 1290 (24.997 sec)
# INFO:tensorflow:lr = 0.00039484748 (24.994 sec)
# INFO:tensorflow:global_step/sec: 4.27611
# INFO:tensorflow:loss = 3.5089815, step = 1390 (23.385 sec)
# INFO:tensorflow:lr = 0.00039445085 (23.387 sec)
# INFO:tensorflow:global_step/sec: 4.16417
# INFO:tensorflow:loss = 3.1988964, step = 1490 (24.014 sec)
# INFO:tensorflow:lr = 0.00039405463 (24.011 sec)
# INFO:tensorflow:global_step/sec: 4.29427
# INFO:tensorflow:loss = 3.0019405, step = 1590 (23.285 sec)
# INFO:tensorflow:lr = 0.00039365876 (23.286 sec)
# INFO:tensorflow:global_step/sec: 4.17258
# INFO:tensorflow:loss = 2.9411108, step = 1690 (23.971 sec)
# INFO:tensorflow:lr = 0.00039326333 (23.970 sec)
# INFO:tensorflow:Saving checkpoints for 1785 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.0023966.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-1785
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 房买不起房
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:00:22Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-1785
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:00:26
# INFO:tensorflow:Saving dict for global step 1785: global_step = 1785, loss = 1.0824164
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1785: ../model/baseline_lstm/model.ckpt-1785
# INFO:tensorflow:Perplexity: 2.952
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-1785
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:BLEU: 68.590, BELU-1: 92.600, BLEU-2: 84.100, BLEU-4: 68.700, EM: 0.354
# INFO:tensorflow:Best BLEU: 68.590
# INFO:tensorflow:Calling model_fn.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-1785
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1785 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 2.7808304, step = 1785
# INFO:tensorflow:lr = 0.00039288803
# INFO:tensorflow:global_step/sec: 3.91221
# INFO:tensorflow:loss = 2.8720782, step = 1885 (25.563 sec)
# INFO:tensorflow:lr = 0.00039249336 (25.556 sec)
# INFO:tensorflow:global_step/sec: 4.17846
# INFO:tensorflow:loss = 2.7956116, step = 1985 (23.937 sec)
# INFO:tensorflow:lr = 0.00039209911 (23.938 sec)
# INFO:tensorflow:global_step/sec: 4.22107
# INFO:tensorflow:loss = 2.7575612, step = 2085 (23.691 sec)
# INFO:tensorflow:lr = 0.00039170525 (23.691 sec)
# INFO:tensorflow:global_step/sec: 4.24096
# INFO:tensorflow:loss = 2.6919765, step = 2185 (23.582 sec)
# INFO:tensorflow:lr = 0.00039131177 (23.583 sec)
# INFO:tensorflow:global_step/sec: 4.14154
# INFO:tensorflow:loss = 2.9289193, step = 2285 (24.139 sec)
# INFO:tensorflow:lr = 0.00039091866 (24.137 sec)
# INFO:tensorflow:Saving checkpoints for 2380 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.7453425.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-2380
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 房房买不起
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:03:20Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-2380
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:03:24
# INFO:tensorflow:Saving dict for global step 2380: global_step = 2380, loss = 0.8968814
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2380: ../model/baseline_lstm/model.ckpt-2380
# INFO:tensorflow:Perplexity: 2.452
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-2380
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:BLEU: 72.200, BELU-1: 94.000, BLEU-2: 86.700, BLEU-4: 73.600, EM: 0.410
# INFO:tensorflow:Best BLEU: 72.200
# INFO:tensorflow:Calling model_fn.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-2380
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2380 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 2.7408884, step = 2380
# INFO:tensorflow:lr = 0.00039054558
# INFO:tensorflow:global_step/sec: 3.80699
# INFO:tensorflow:loss = 2.843783, step = 2480 (26.270 sec)
# INFO:tensorflow:lr = 0.00039015326 (26.256 sec)
# INFO:tensorflow:global_step/sec: 4.40189
# INFO:tensorflow:loss = 2.8129401, step = 2580 (22.721 sec)
# INFO:tensorflow:lr = 0.00038976135 (22.723 sec)
# INFO:tensorflow:global_step/sec: 4.00648
# INFO:tensorflow:loss = 2.7130175, step = 2680 (24.956 sec)
# INFO:tensorflow:lr = 0.00038936984 (24.953 sec)
# INFO:tensorflow:global_step/sec: 4.28558
# INFO:tensorflow:loss = 2.729484, step = 2780 (23.333 sec)
# INFO:tensorflow:lr = 0.0003889787 (23.333 sec)
# INFO:tensorflow:global_step/sec: 4.45561
# INFO:tensorflow:loss = 2.683089, step = 2880 (22.444 sec)
# INFO:tensorflow:lr = 0.00038858797 (22.445 sec)
# INFO:tensorflow:Saving checkpoints for 2975 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.6119812.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-2975
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 房子买不起
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:06:15Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-2975
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:06:19
# INFO:tensorflow:Saving dict for global step 2975: global_step = 2975, loss = 0.81080794
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2975: ../model/baseline_lstm/model.ckpt-2975
# INFO:tensorflow:Perplexity: 2.250
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-2975
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:BLEU: 75.240, BELU-1: 94.400, BLEU-2: 87.900, BLEU-4: 75.500, EM: 0.465
# INFO:tensorflow:Best BLEU: 75.240
# INFO:tensorflow:Calling model_fn.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-2975
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2975 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 2.7662613, step = 2975
# INFO:tensorflow:lr = 0.00038821713
# INFO:tensorflow:global_step/sec: 3.8486
# INFO:tensorflow:loss = 2.621286, step = 3075 (25.987 sec)
# INFO:tensorflow:lr = 0.00038782714 (25.994 sec)
# INFO:tensorflow:global_step/sec: 4.28883
# INFO:tensorflow:loss = 2.6328928, step = 3175 (23.320 sec)
# INFO:tensorflow:lr = 0.00038743758 (23.311 sec)
# INFO:tensorflow:global_step/sec: 4.07727
# INFO:tensorflow:loss = 2.5835404, step = 3275 (24.525 sec)
# INFO:tensorflow:lr = 0.00038704838 (24.527 sec)
# INFO:tensorflow:global_step/sec: 4.022
# INFO:tensorflow:loss = 2.6791523, step = 3375 (24.865 sec)
# INFO:tensorflow:lr = 0.00038665958 (24.864 sec)
# INFO:tensorflow:global_step/sec: 4.44315
# INFO:tensorflow:loss = 2.6505947, step = 3475 (22.507 sec)
# INFO:tensorflow:lr = 0.00038627116 (22.505 sec)
# INFO:tensorflow:Saving checkpoints for 3570 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.8393593.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-3570
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 房子买不起
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:09:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-3570
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:09:16
# INFO:tensorflow:Saving dict for global step 3570: global_step = 3570, loss = 0.774197
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3570: ../model/baseline_lstm/model.ckpt-3570
# INFO:tensorflow:Perplexity: 2.169
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-3570
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:BLEU: 75.480, BELU-1: 94.200, BLEU-2: 87.200, BLEU-4: 74.100, EM: 0.455
# INFO:tensorflow:Best BLEU: 75.480
# INFO:tensorflow:Calling model_fn.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-3570
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3570 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 2.421744, step = 3570
# INFO:tensorflow:lr = 0.00038590253
# INFO:tensorflow:global_step/sec: 3.86244
# INFO:tensorflow:loss = 2.5771675, step = 3670 (25.893 sec)
# INFO:tensorflow:lr = 0.0003855149 (25.893 sec)
# INFO:tensorflow:global_step/sec: 4.26942
# INFO:tensorflow:loss = 2.5423586, step = 3770 (23.428 sec)
# INFO:tensorflow:lr = 0.00038512764 (23.430 sec)
# INFO:tensorflow:global_step/sec: 4.1805
# INFO:tensorflow:loss = 2.5912468, step = 3870 (23.914 sec)
# INFO:tensorflow:lr = 0.00038474074 (23.912 sec)
# INFO:tensorflow:global_step/sec: 4.34638
# INFO:tensorflow:loss = 2.5873854, step = 3970 (23.015 sec)
# INFO:tensorflow:lr = 0.00038435427 (23.015 sec)
# INFO:tensorflow:global_step/sec: 4.36236
# INFO:tensorflow:loss = 2.4896548, step = 4070 (22.922 sec)
# INFO:tensorflow:lr = 0.00038396817 (22.922 sec)
# INFO:tensorflow:Saving checkpoints for 4165 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.494747.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-4165
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 房子买不起
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:12:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-4165
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:12:11
# INFO:tensorflow:Saving dict for global step 4165: global_step = 4165, loss = 0.74131835
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4165: ../model/baseline_lstm/model.ckpt-4165
# INFO:tensorflow:Perplexity: 2.099
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-4165
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:BLEU: 76.490, BELU-1: 94.900, BLEU-2: 88.800, BLEU-4: 77.000, EM: 0.496
# INFO:tensorflow:Best BLEU: 76.490
# INFO:tensorflow:Calling model_fn.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-4165
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4165 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 2.487659, step = 4165
# INFO:tensorflow:lr = 0.00038360176
# INFO:tensorflow:global_step/sec: 3.8529
# INFO:tensorflow:loss = 2.701804, step = 4265 (25.964 sec)
# INFO:tensorflow:lr = 0.00038321642 (25.963 sec)
# INFO:tensorflow:global_step/sec: 4.17299
# INFO:tensorflow:loss = 2.4926505, step = 4365 (23.962 sec)
# INFO:tensorflow:lr = 0.00038283147 (23.963 sec)
# INFO:tensorflow:global_step/sec: 4.15723
# INFO:tensorflow:loss = 2.5670779, step = 4465 (24.050 sec)
# INFO:tensorflow:lr = 0.0003824469 (24.055 sec)
# INFO:tensorflow:global_step/sec: 4.23355
# INFO:tensorflow:loss = 2.4965088, step = 4565 (23.625 sec)
# INFO:tensorflow:lr = 0.00038206275 (23.619 sec)
# INFO:tensorflow:global_step/sec: 4.23493
# INFO:tensorflow:loss = 2.5297453, step = 4665 (23.615 sec)
# INFO:tensorflow:lr = 0.0003816789 (23.615 sec)
# INFO:tensorflow:Saving checkpoints for 4760 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.5936496.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-4760
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 买不起房子
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:15:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-4760
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:15:09
# INFO:tensorflow:Saving dict for global step 4760: global_step = 4760, loss = 0.7048477
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4760: ../model/baseline_lstm/model.ckpt-4760
# INFO:tensorflow:Perplexity: 2.024
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-4760
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:BLEU: 77.940, BELU-1: 94.400, BLEU-2: 87.900, BLEU-4: 75.500, EM: 0.499
# INFO:tensorflow:Best BLEU: 77.940
# INFO:tensorflow:Calling model_fn.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-4760
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4760 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 2.4090588, step = 4760
# INFO:tensorflow:lr = 0.00038131466
# INFO:tensorflow:global_step/sec: 3.9092
# INFO:tensorflow:loss = 2.4467232, step = 4860 (25.590 sec)
# INFO:tensorflow:lr = 0.0003809316 (25.590 sec)
# INFO:tensorflow:global_step/sec: 3.9834
# INFO:tensorflow:loss = 2.5353258, step = 4960 (25.104 sec)
# INFO:tensorflow:lr = 0.00038054897 (25.104 sec)
# INFO:tensorflow:global_step/sec: 4.37599
# INFO:tensorflow:loss = 2.442298, step = 5060 (22.852 sec)
# INFO:tensorflow:lr = 0.0003801667 (22.852 sec)
# INFO:tensorflow:global_step/sec: 4.41753
# INFO:tensorflow:loss = 2.445806, step = 5160 (22.638 sec)
# INFO:tensorflow:lr = 0.00037978482 (22.638 sec)
# INFO:tensorflow:global_step/sec: 4.16747
# INFO:tensorflow:loss = 2.4493523, step = 5260 (23.994 sec)
# INFO:tensorflow:lr = 0.00037940333 (23.995 sec)
# INFO:tensorflow:Saving checkpoints for 5355 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.585247.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-5355
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 买不起房子
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T06:18:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-5355
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-06:18:05
# INFO:tensorflow:Saving dict for global step 5355: global_step = 5355, loss = 0.681607
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5355: ../model/baseline_lstm/model.ckpt-5355
# INFO:tensorflow:Perplexity: 1.977
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# ...
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-19040
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 19040 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 2.2359018, step = 19040
# INFO:tensorflow:lr = 0.00033033465
# INFO:tensorflow:global_step/sec: 3.88621
# INFO:tensorflow:loss = 2.2457302, step = 19140 (25.744 sec)
# INFO:tensorflow:lr = 0.00033000283 (25.748 sec)
# INFO:tensorflow:global_step/sec: 4.29021
# INFO:tensorflow:loss = 2.2568803, step = 19240 (23.298 sec)
# INFO:tensorflow:lr = 0.00032967134 (23.296 sec)
# INFO:tensorflow:global_step/sec: 4.22322
# INFO:tensorflow:loss = 2.2538655, step = 19340 (23.678 sec)
# INFO:tensorflow:lr = 0.00032934017 (23.677 sec)
# INFO:tensorflow:global_step/sec: 4.13258
# INFO:tensorflow:loss = 2.2564037, step = 19440 (24.205 sec)
# INFO:tensorflow:lr = 0.00032900934 (24.208 sec)
# INFO:tensorflow:global_step/sec: 4.17652
# INFO:tensorflow:loss = 2.2566323, step = 19540 (23.939 sec)
# INFO:tensorflow:lr = 0.00032867887 (23.939 sec)
# INFO:tensorflow:Saving checkpoints for 19635 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.248107.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-19635
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 买不起房子
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T07:28:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-19635
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-07:28:25
# INFO:tensorflow:Saving dict for global step 19635: global_step = 19635, loss = 0.7395914
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 19635: ../model/baseline_lstm/model.ckpt-19635
# INFO:tensorflow:Perplexity: 2.095
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-19635
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:BLEU: 80.930, BELU-1: 94.300, BLEU-2: 88.400, BLEU-4: 77.300, EM: 0.564
# INFO:tensorflow:Best BLEU: 81.360
# INFO:tensorflow:Calling model_fn.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-19635
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 19635 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 2.248703, step = 19635
# INFO:tensorflow:lr = 0.00032836516
# INFO:tensorflow:global_step/sec: 4.03436
# INFO:tensorflow:loss = 2.240738, step = 19735 (24.795 sec)
# INFO:tensorflow:lr = 0.00032803533 (24.792 sec)
# INFO:tensorflow:global_step/sec: 4.1901
# INFO:tensorflow:loss = 2.2427754, step = 19835 (23.862 sec)
# INFO:tensorflow:lr = 0.0003277058 (23.867 sec)
# INFO:tensorflow:global_step/sec: 4.006
# INFO:tensorflow:loss = 2.2365398, step = 19935 (24.968 sec)
# INFO:tensorflow:lr = 0.0003273766 (24.965 sec)
# INFO:tensorflow:global_step/sec: 4.20816
# INFO:tensorflow:loss = 2.2454221, step = 20035 (23.766 sec)
# INFO:tensorflow:lr = 0.00032704775 (23.763 sec)
# INFO:tensorflow:global_step/sec: 4.24783
# INFO:tensorflow:loss = 2.2466965, step = 20135 (23.533 sec)
# INFO:tensorflow:lr = 0.0003267192 (23.533 sec)
# INFO:tensorflow:Saving checkpoints for 20230 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.246008.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-20230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 买不起房子
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T07:31:16Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-20230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-07:31:20
# INFO:tensorflow:Saving dict for global step 20230: global_step = 20230, loss = 0.74617916
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20230: ../model/baseline_lstm/model.ckpt-20230
# INFO:tensorflow:Perplexity: 2.109
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-20230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:BLEU: 81.710, BELU-1: 94.800, BLEU-2: 89.000, BLEU-4: 78.300, EM: 0.575
# INFO:tensorflow:Best BLEU: 81.710
# INFO:tensorflow:Calling model_fn.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-20230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 20230 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 2.2490613, step = 20230
# INFO:tensorflow:lr = 0.00032640743
# INFO:tensorflow:global_step/sec: 3.94399
# INFO:tensorflow:loss = 2.2357454, step = 20330 (25.364 sec)
# INFO:tensorflow:lr = 0.00032607952 (25.364 sec)
# INFO:tensorflow:global_step/sec: 4.24344
# INFO:tensorflow:loss = 2.2356188, step = 20430 (23.567 sec)
# INFO:tensorflow:lr = 0.000325752 (23.567 sec)
# INFO:tensorflow:global_step/sec: 4.11833
# INFO:tensorflow:loss = 2.2531326, step = 20530 (24.283 sec)
# INFO:tensorflow:lr = 0.00032542477 (24.282 sec)
# INFO:tensorflow:global_step/sec: 4.33012
# INFO:tensorflow:loss = 2.2363374, step = 20630 (23.085 sec)
# INFO:tensorflow:lr = 0.00032509788 (23.086 sec)
# INFO:tensorflow:global_step/sec: 4.40689
# INFO:tensorflow:loss = 2.2477882, step = 20730 (22.702 sec)
# INFO:tensorflow:lr = 0.0003247713 (22.702 sec)
# INFO:tensorflow:Saving checkpoints for 20825 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.2274642.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-20825
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# minimal test
# Q: 房子好贵|房价涨房租跟着涨|买不起
# A: 买不起房子
# ------------
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-09T07:34:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-20825
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-09-07:34:13
# INFO:tensorflow:Saving dict for global step 20825: global_step = 20825, loss = 0.7453281
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20825: ../model/baseline_lstm/model.ckpt-20825
# INFO:tensorflow:Perplexity: 2.107
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-20825
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:BLEU: 81.400, BELU-1: 94.500, BLEU-2: 88.600, BLEU-4: 77.800, EM: 0.560
# INFO:tensorflow:Best BLEU: 81.710
# INFO:tensorflow:Calling model_fn.
# [<tf.Variable 'Embedding/fasttext_vectors:0' shape=(3879, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/lstm_fused_cell_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/feature_projection/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/attn_proj_2/bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/kernel:0' shape=(900, 300) dtype=float32_ref>,
#  <tf.Variable 'Dynamic_Memory/memory_proj/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer_1/kernel:0' shape=(900, 150) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3879,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/baseline_lstm/model.ckpt-20825
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 20825 into ../model/baseline_lstm/model.ckpt.
# INFO:tensorflow:loss = 2.2443812, step = 20825
# INFO:tensorflow:lr = 0.00032446138
