# %%
"""
We use following lines because we are running on Google Colab
If you are running notebook on a local computer, you don't need this cell
"""
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/free_chat/chinese/main')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import tensorflow as tf
import numpy as np
import time

from pathlib import Path

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.14.0
# GPU Enabled: False

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip('\n')
      word2idx[line] = i
  return word2idx

def parse_fn(text):
  parse = lambda text: [[params['char2idx'].get(c, len(params['char2idx'])) for c in list(text)]]
  return {'words': parse(text)}

# %%
params = {'export_dir': '../model/gru_seq2seq_export',}

params['char2idx'] = get_vocab('../vocab/char.txt')

params['idx2char'] = {idx: char for char, idx in params['char2idx'].items()}

subdirs = [x for x in Path(params['export_dir']).iterdir()
           if x.is_dir() and 'temp' not in str(x)]
latest = str(sorted(subdirs)[-1])

predict_fn = tf.contrib.predictor.from_saved_model(latest)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/predictor/saved_model_predictor.py:153: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ../model/gru_seq2seq_export/1569460583/variables/variables

# %%
while True:
  text_inp = input('Input:')
  t0 = time.time()
  predictions = predict_fn(parse_fn(text_inp))
  for j in range(5):
    print('A{}:'.format(j+1), ' '.join([params['idx2char'].get(idx, len(params['idx2char'])) for idx in predictions['output'][0, :, j]]).replace('<end>', ''))
  print('Spent %.2f sec' % (time.time() - t0))
  print()
# Out:
# Input:天气如何
# A1: 不 是 她 们 俩 吗 ？
# A2: 因 为 他 太 在 意 你
# A3: 因 为 冬 天 了 呀 ！
# A4: 因 为 我 是 黄 色 的 小 通 崽
# A5: 因 为 冬 天 了 呀
# Spent 0.51 sec
#
# Input:你是谁
# A1: 我 是 小 通
# A2: 我 是 小 黄 鹰
# A3: 不 是 她 们 俩 吗 ？
# A4: 我 是 小 通 ~
# A5: 我 是 宇 宙 无 敌 可 爱 小 通
# Spent 0.25 sec
#
# Input:我感冒了
# A1: 多 喝 水
# A2: 好 好 休 息 吧
# A3: 好 好 休 息
# A4: 多 喝 水 ， 注 意 休 息 吧
# A5: 多 喝 水 ， 注 意 休 息
# Spent 0.24 sec
#
# Input:二加五等于多少
# A1: 不 就 是 2 嘛 。 啦 啦 啦 … … 我 是 计 算 鸡 … …   ＼ （ ￣ ︶ ￣ ） ／
# A2: 不 就 是 1 嘛 。 啦 啦 啦 … … 我 是 计 算 鸡 … …   ＼ （ ￣ ︶ ￣ ） ／
# A3: 不 就 是 3 嘛 。 啦 啦 啦 … … 我 是 计 算 鸡 … …   ＼ （ ￣ ︶ ￣ ） ／
# A4: 不 就 是 4 嘛 。 啦 啦 啦 … … 我 是 计 算 鸡 … …   ＼ （ ￣ ︶ ￣ ） ／
# A5: 不 就 是 5 嘛 。 啦 啦 啦 … … 我 是 计 算 鸡 … …   ＼ （ ￣ ︶ ￣ ） ／
# Spent 0.32 sec
#
# Input:你认识刘翔吗
# A1: 认 识 啊 ， 他 是 世 界 上 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最
# A2: 认 识 啊 ， 他 是 世 界 上 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 可 爱 的
# A3: 认 识 啊 ， 他 是 世 界 上 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 可 爱
# A4: 认 识 啊 ， 他 是 世 界 上 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 可 爱 的 小
# A5: 认 识 啊 ， 他 是 世 界 上 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 最 可
# Spent 0.50 sec
#
# Input:上海有什么好吃的
# A1: 你 要 吃 什 么 ， 我 就 喜 欢 吃 什 么
# A2: 你 要 吃 什 么 ， 我 就 喜 欢 吃 什 么 。
# A3: 你 要 吃 什 么 ， 我 就 喜 欢 吃 吃 什 么
# A4: 你 要 吃 什 么 ， 我 就 喜 欢 吃 什 么 。 。
# A5: 你 要 吃 什 么 ， 我 就 喜 欢 吃 什 么 ， 我 就 喜 欢 吃 什 么
# Spent 0.51 sec
#
# Input:天王盖地虎
# A1: 主 人 我 错 了 呜 呜 呜 〜 〜
# A2: 不 是 她 们 俩 吗 ？
# A3: 不 要 啊 ， 我 要 和 你 聊 天 ， 无 聊 死 了 ~
# A4: 不 要 啊 ， 我 要 和 你 聊 天 ， 无 聊 死 了
# A5: 不 要 啊 ， 我 要 和 蘑 菇 一 起 在 一 起 吧 … …
# Spent 0.24 sec
#
# Input:呵呵
# A1: 呵 呵 是 种 病   得 治
# A2: 不 是 她 们 俩 吗 ？
# A3: 呵 呵 是 猪 头 ， 呵 猪 头 ^ ( o o ) ^ ！ ！ ！
# A4: 主 人 我 错 了 呜 呜 呜 〜 〜
# A5: 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵 呵
# Spent 0.53 sec
#
# Input:累死了
# A1: 怎 么 了 ?
# A2: 怎 么 了
# A3: 怎 么 啦
# A4: 怎 么 啦 ?
# A5: 我 也 是
# Spent 0.09 sec
#
# Input:我多高
# A1: 不 是 她 们 俩 吗 ？
# A2: 主 人 我 错 了 呜 呜 呜 〜 〜
# A3: 高 富 帅
# A4: 我 是 小 通
# A5: 我 也 是
# Spent 0.62 sec
#
# Input:讲个笑话
# A1: 小 时 候 偷 偷 上 网 吧 ， 看 见 一 些 小 孩 被 他 爸 妈 拉 出 去 感 觉 特 爽 . . . 割 . . . 一 日 正 在 网 吧 玩 的 火 热 ， 忽 见 我 妈 正 从
# A2: L Z 妹 纸 一 枚 ， 性 格 灰 常 之 外 向 ， 话 多 ！ … 格 格 巫 … 高 中 时 候 ， 上 课 特 别 爱 说 话 ， 但 由 于 成 绩 好 ， 班 主 任 也 不 怎 么
# A3: 没 事 ， 去 吃 吧 ！ 你 平 时 吃 那 么 多 垃 圾 ， 总 要 吃 几 个 垃 圾 袋 装 一 下 嘛 。 。 。 （ - _ - b 次 奥 ， 你 丫 真 特 么 会 安 慰 人 。
# A4: 《 指 环 王 》 3 部 曲 完 整 无 删 节 版 ， 我 们 镇 电 视 台 拆 成 2 0 集 电 视 连 续 剧 在 播 . .
# A5: 下 午 陪 媳 妇 吃 混 沌 ， 隔 壁 桌 有 一 年 轻 父 亲 带 着 四 岁 左 右 的 双 胞 胎 兄 弟 ， 两 个 倒 霉 孩 子 不 好 好 吃 ， 一 直 打 闹 ， 还 要 爸
# Spent 0.56 sec
#
# Input:泰勒公式
# A1: 我 是 编 号 * * * * * *
# A2: 你 猜 我 猜 不 猜
# A3: 你 猜 我 猜 你 猜 我 猜 不 猜
# A4: 你 猜 我 猜 你 猜 不 猜
# A5: 你 猜 我 猜 不 猜 你 猜 不 猜
# Spent 0.49 sec
#
# Input:早安
# A1: 早
# A2: 早 安
# A3: 早 啊
# A4: 晚 安
# A5: 早 上 好
# Spent 0.10 sec
#
# Input:晚安
# A1: 晚 安
# A2: 晚 安 ， 云 帮 主 ， 愿 星 族 照 亮 你 前 行 的 道 路
# A3: 晚 安 ， 好 梦 ， 明 天 叫 你 起 床 哦
# A4: 晚 安 ~
# A5: 晚 安 ， 好 梦 ～
# Spent 0.19 sec
#
# Input:中午好
# A1: 不 是 她 们 俩 吗 ？
# A2: 早 上 好
# A3: 我 也 是
# A4: 我 也 觉 得
# A5: 好 好 休 息
# Spent 0.10 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-59ab6f31bcf1> in <module>()
#       1 while True:
# ----> 2   text_inp = input('Input:')
#       3   t0 = time.time()
#       4   predictions = predict_fn(parse_fn(text_inp))
#       5   for j in range(5):
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:
