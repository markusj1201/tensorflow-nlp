# %%
"""
We use following lines because we are running on Google Colab
If you are running notebook on a local computer, you don't need these
"""
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/recommender/movielens/main')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import tensorflow as tf
print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
import pprint
import logging

from pathlib import Path
# Out:
# TensorFlow Version 1.14.0
# GPU Enabled: True

# %%
# stream data from text files
def gen_fn(f_path):
  movietype2idx = {}
  with open('../vocab/movie_types.txt') as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      movietype2idx[line] = i
  
  with open(f_path) as f:
    print('Reading', f_path)
    for line in f:
      line = line.rstrip()
      (user_id, user_gender, user_age, user_job, movie_id, movie_types, movie_title, score) = line.split('\t')
      
      movie_types_ = [0] * len(movietype2idx)
      for movie_type in movie_types.split():
        movie_types_[movietype2idx[movie_type]] = 1
        
      movie_title = movie_title.split()
      yield (user_id, user_age, user_job, user_gender, movie_id, movie_types_, movie_title), score


def input_fn(mode, params):
  _shapes = (([], [], [], [], [], [18], [None]), [])
  _types = ((tf.string, tf.string, tf.string, tf.string, tf.string, tf.int32, tf.string), tf.float32)
  _pads = (('-1', '-1', '-1', '-1', '-1', -1, '<pad>'), 0.)
  
  if mode == tf.estimator.ModeKeys.TRAIN:
    ds = tf.data.Dataset.from_generator(
      lambda: gen_fn('../data/train.txt'),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.repeat()
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    
  if mode == tf.estimator.ModeKeys.EVAL:
    ds = tf.data.Dataset.from_generator(
      lambda: gen_fn('../data/test.txt'),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  return ds

# %%
def model_fn(features, labels, mode, params):
  # Receive inputs
  user_id, user_age, user_job, user_gender, movie_id, movie_types, movie_title = features
  
  
  # Flag for Dropout / Batch Norm
  is_training = (mode == tf.estimator.ModeKeys.TRAIN)
  
  
  # Word Indexing
  lookup_user_id = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_id.txt', num_oov_buckets=1)
  
  lookup_user_age = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_age.txt', num_oov_buckets=1)
  
  lookup_user_job = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_job.txt', num_oov_buckets=1)
  
  lookup_user_gender = tf.contrib.lookup.index_table_from_file(
    '../vocab/user_gender.txt', num_oov_buckets=1)
  
  lookup_movie_id = tf.contrib.lookup.index_table_from_file(
    '../vocab/movie_id.txt', num_oov_buckets=1)
  
  lookup_movie_title = tf.contrib.lookup.index_table_from_file(
    '../vocab/movie_title.txt', num_oov_buckets=1)
  
  user_id = lookup_user_id.lookup(user_id)
  
  user_age = lookup_user_age.lookup(user_age)
  
  user_job = lookup_user_job.lookup(user_job)
  
  user_gender = lookup_user_gender.lookup(user_gender)
  
  movie_id = lookup_movie_id.lookup(movie_id)
  
  movie_title = lookup_movie_title.lookup(movie_title)
  
  
  # Embedding
  user_id = tf.contrib.layers.embed_sequence(
    ids = user_id,
    vocab_size = params['user_id_size'] + 1,
    embed_dim = params['large_embed_dim'],
    scope='user_id')
  
  user_age = tf.contrib.layers.embed_sequence(
    ids = user_age,
    vocab_size = params['user_age_size'] + 1,
    embed_dim = params['small_embed_dim'],
    scope='user_age')
  
  user_job = tf.contrib.layers.embed_sequence(
    ids = user_job,
    vocab_size = params['user_job_size'] + 1,
    embed_dim = params['small_embed_dim'],
    scope='user_job')
  
  user_gender = tf.contrib.layers.embed_sequence(
    ids = user_gender,
    vocab_size = params['user_gender_size'],
    embed_dim = params['small_embed_dim'],
    scope='user_gender')
  
  movie_id = tf.contrib.layers.embed_sequence(
    ids = movie_id,
    vocab_size = params['movie_id_size'] + 1,
    embed_dim = params['large_embed_dim'],
    scope='movie_id')
  
  movie_types = tf.to_float(movie_types)
  
  movie_title = tf.contrib.layers.embed_sequence(
    ids = movie_title,
    vocab_size = params['movie_title_size'] + 1,
    embed_dim = params['large_embed_dim'],
    scope='movie_title')
  
  
  # User Network
  user_feature = tf.concat((user_id, user_age, user_job, user_gender), -1)
  
  user_feature = tf.layers.dropout(user_feature, params['dropout_rate'], training=is_training)
  
  user_feature = tf.layers.dense(user_feature,
                                 params['hidden_dim'],
                                 params['activation'],
                                 name='user_feature/fc')
  
  
  # Movie Network
  movie_title = tf.layers.dropout(movie_title, params['dropout_rate'], training=is_training)
  
  movie_title = tf.reduce_max(tf.layers.conv1d(movie_title,
                                               filters=params['large_embed_dim'],
                                               kernel_size=params['kernel_size'],
                                               activation=params['activation'],
                                               name='movie_feature/conv1d'), axis=1)
  
  movie_feature = tf.concat((movie_id, movie_types, movie_title), -1)
  
  movie_feature = tf.layers.dropout(movie_feature, params['dropout_rate'], training=is_training)
  
  movie_feature = tf.layers.dense(movie_feature,
                                  params['hidden_dim'],
                                  params['activation'],
                                  name='movie_feature/fc')
  
  
  # Aggregation
  scores = tf.concat([tf.abs(user_feature - movie_feature),
                      user_feature * movie_feature,
                      user_feature,
                      movie_feature], -1)
  scores = tf.layers.dropout(scores, params['dropout_rate'], training=is_training)
  scores = tf.layers.dense(scores, params['hidden_dim'], params['activation'])
  scores = tf.layers.dropout(scores, params['dropout_rate'], training=is_training)
  scores = tf.layers.dense(scores, params['hidden_dim'], params['activation'])
  scores = tf.layers.dense(scores, 1)
  scores = tf.squeeze(scores, -1)
  predictions = 5. * tf.sigmoid(scores)
  
  
  if labels is not None:
    labels = (labels + 5.) / 2.
    loss_op = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
      labels=labels/5., logits=scores))
  
  
  if mode == tf.estimator.ModeKeys.TRAIN:
    tf.logging.info('\n'+pprint.pformat(tf.trainable_variables()))
    
    global_step=tf.train.get_or_create_global_step()
    decay_lr = tf.train.exponential_decay(
      params['lr'], global_step, 1000, .96)
    
    optim = tf.train.AdamOptimizer(decay_lr)
    train_op = optim.minimize(
      loss_op, global_step=tf.train.get_or_create_global_step())
    
    hook = tf.train.LoggingTensorHook({'lr': decay_lr}, every_n_iter=100)
    
    return tf.estimator.EstimatorSpec(mode=mode,
                                      loss=loss_op,
                                      train_op=train_op,
                                      training_hooks=[hook],)
  
  
  if mode == tf.estimator.ModeKeys.EVAL:
    mae_op = tf.metrics.mean_absolute_error(labels=labels,
                                            predictions=predictions)
    return tf.estimator.EstimatorSpec(mode=mode,
                                      loss=loss_op,
                                      eval_metric_ops={'mae': mae_op})

# %%
params = {
    'log_path': '../log/dnn.txt',
    'model_dir': '../model/dnn',
    'user_id_size': 6040,
    'user_age_size': 7,
    'user_job_size': 21,
    'user_gender_size': 2,
    'movie_id_size': 3691,
    'movie_title_size': 3761,
    'small_embed_dim': 30,
    'large_embed_dim': 200,
    'hidden_dim': 200,
    'activation': tf.nn.elu,
    'kernel_size': 3,
    'dropout_rate': 0.2,
    'lr': 3e-4,
    'num_patience': 7,
    'buffer_size': int(6E5),
    'batch_size': 256,
}

# %%
# Create directory if not exist
Path(os.path.dirname(params['log_path'])).mkdir(exist_ok=True)
Path(params['model_dir']).mkdir(exist_ok=True, parents=True)

# Logging
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)
fh = logging.FileHandler(params['log_path'])
logger.addHandler(fh)

# Create an estimator
config = tf.estimator.RunConfig(
  save_checkpoints_steps=params['buffer_size']//params['batch_size'],
  keep_checkpoint_max=params['num_patience']+2,)

estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  model_dir=params['model_dir'],
  config=config,
  params=params)

# This hook early-stops model if testing accuracy is not improved
hook = tf.estimator.experimental.stop_if_no_decrease_hook(
  estimator=estimator,
  metric_name='mae',
  max_steps_without_decrease=params['num_patience']*params['buffer_size']//params['batch_size'],
  run_every_secs=None,
  run_every_steps=params['buffer_size']//params['batch_size'])

# Train on training data and Evaluate on testing data
train_spec = tf.estimator.TrainSpec(
  input_fn=lambda: input_fn(mode=tf.estimator.ModeKeys.TRAIN,
                            params=params),
  hooks=[hook])

eval_spec = tf.estimator.EvalSpec(
  input_fn=lambda: input_fn(mode=tf.estimator.ModeKeys.EVAL,
                            params=params),
  steps=None,
  throttle_secs=10,)

tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
139621405767552 basic_session_run_hooks.py:260] lr = 0.0002915487 (5.820 sec)
# I0709 01:57:29.649405 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.8965
# I0709 01:57:29.652002 139621405767552 basic_session_run_hooks.py:260] loss = 0.5564095, step = 800 (5.919 sec)
# I0709 01:57:29.656358 139621405767552 basic_session_run_hooks.py:260] lr = 0.00029036097 (5.921 sec)
# I0709 01:57:35.600542 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.8035
# I0709 01:57:35.602501 139621405767552 basic_session_run_hooks.py:260] loss = 0.56786567, step = 900 (5.950 sec)
# I0709 01:57:35.606604 139621405767552 basic_session_run_hooks.py:260] lr = 0.00028917808 (5.950 sec)
# I0709 01:57:41.510172 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.9215
# I0709 01:57:41.515433 139621405767552 basic_session_run_hooks.py:260] loss = 0.55323786, step = 1000 (5.913 sec)
# I0709 01:57:41.517001 139621405767552 basic_session_run_hooks.py:260] lr = 0.000288 (5.910 sec)
# I0709 01:57:47.362786 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 17.0864
# I0709 01:57:47.365918 139621405767552 basic_session_run_hooks.py:260] loss = 0.55988705, step = 1100 (5.850 sec)
# I0709 01:57:47.370102 139621405767552 basic_session_run_hooks.py:260] lr = 0.00028682672 (5.853 sec)
# Reading ../data/train.txt
# I0709 01:57:53.259103 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.9598
# I0709 01:57:53.262758 139621405767552 basic_session_run_hooks.py:260] loss = 0.5385315, step = 1200 (5.897 sec)
# I0709 01:57:53.265128 139621405767552 basic_session_run_hooks.py:260] lr = 0.00028565823 (5.895 sec)
# I0709 01:57:59.110134 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 17.091
# I0709 01:57:59.115243 139621405767552 basic_session_run_hooks.py:260] loss = 0.5532668, step = 1300 (5.852 sec)
# I0709 01:57:59.117090 139621405767552 basic_session_run_hooks.py:260] lr = 0.00028449448 (5.852 sec)
# I0709 01:58:04.988655 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 17.0111
# I0709 01:58:04.990632 139621405767552 basic_session_run_hooks.py:260] loss = 0.581186, step = 1400 (5.875 sec)
# I0709 01:58:04.993137 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002833355 (5.876 sec)
# I0709 01:58:10.930296 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.8304
# I0709 01:58:10.934026 139621405767552 basic_session_run_hooks.py:260] loss = 0.55791116, step = 1500 (5.943 sec)
# I0709 01:58:10.938654 139621405767552 basic_session_run_hooks.py:260] lr = 0.00028218122 (5.946 sec)
# I0709 01:58:16.843918 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.9101
# I0709 01:58:16.848925 139621405767552 basic_session_run_hooks.py:260] loss = 0.5744897, step = 1600 (5.915 sec)
# I0709 01:58:16.850627 139621405767552 basic_session_run_hooks.py:260] lr = 0.00028103162 (5.912 sec)
# I0709 01:58:22.881307 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5635
# I0709 01:58:22.883778 139621405767552 basic_session_run_hooks.py:260] loss = 0.52511746, step = 1700 (6.035 sec)
# I0709 01:58:22.890133 139621405767552 basic_session_run_hooks.py:260] lr = 0.00027988676 (6.039 sec)
# I0709 01:58:28.763851 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.9995
# I0709 01:58:28.767579 139621405767552 basic_session_run_hooks.py:260] loss = 0.55123025, step = 1800 (5.884 sec)
# I0709 01:58:28.770238 139621405767552 basic_session_run_hooks.py:260] lr = 0.00027874653 (5.880 sec)
# I0709 01:58:34.619782 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 17.0767
# I0709 01:58:34.623334 139621405767552 basic_session_run_hooks.py:260] loss = 0.5877038, step = 1900 (5.856 sec)
# I0709 01:58:34.626157 139621405767552 basic_session_run_hooks.py:260] lr = 0.00027761093 (5.856 sec)
# I0709 01:58:40.489758 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 17.
139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.9262
# I0709 02:00:01.005004 139621405767552 basic_session_run_hooks.py:260] loss = 0.5372963, step = 3000 (5.909 sec)
# I0709 02:00:01.006505 139621405767552 basic_session_run_hooks.py:260] lr = 0.00026542076 (5.908 sec)
# I0709 02:00:06.861603 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 17.0596
# I0709 02:00:06.865744 139621405767552 basic_session_run_hooks.py:260] loss = 0.5560584, step = 3100 (5.861 sec)
# I0709 02:00:06.867954 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002643395 (5.861 sec)
# I0709 02:00:12.750104 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.9822
# I0709 02:00:12.751926 139621405767552 basic_session_run_hooks.py:260] loss = 0.55559015, step = 3200 (5.886 sec)
# I0709 02:00:12.755903 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002632626 (5.888 sec)
# I0709 02:00:18.609329 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 17.0671
# I0709 02:00:18.615058 139621405767552 basic_session_run_hooks.py:260] loss = 0.5665309, step = 3300 (5.863 sec)
# I0709 02:00:18.616680 139621405767552 basic_session_run_hooks.py:260] lr = 0.00026219012 (5.861 sec)
# I0709 02:00:24.479955 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 17.034
# I0709 02:00:24.485311 139621405767552 basic_session_run_hooks.py:260] loss = 0.5525504, step = 3400 (5.870 sec)
# I0709 02:00:24.486862 139621405767552 basic_session_run_hooks.py:260] lr = 0.00026112198 (5.870 sec)
# I0709 02:00:30.394700 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.9069
# I0709 02:00:30.397897 139621405767552 basic_session_run_hooks.py:260] loss = 0.54274535, step = 3500 (5.913 sec)
# I0709 02:00:30.401118 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002600582 (5.914 sec)
# I0709 02:00:36.311553 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.9009
# I0709 02:00:36.315257 139621405767552 basic_session_run_hooks.py:260] loss = 0.578523, step = 3600 (5.917 sec)
# I0709 02:00:36.316537 139621405767552 basic_session_run_hooks.py:260] lr = 0.00025899877 (5.915 sec)
# I0709 02:00:42.249756 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.8401
# I0709 02:00:42.254058 139621405767552 basic_session_run_hooks.py:260] loss = 0.5604878, step = 3700 (5.939 sec)
# I0709 02:00:42.256533 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002579436 (5.940 sec)
# I0709 02:00:48.246503 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6757
# I0709 02:00:48.248996 139621405767552 basic_session_run_hooks.py:260] loss = 0.55868244, step = 3800 (5.995 sec)
# I0709 02:00:48.251674 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002568928 (5.995 sec)
# I0709 02:00:54.288884 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5497
# I0709 02:00:54.293292 139621405767552 basic_session_run_hooks.py:260] loss = 0.5664669, step = 3900 (6.044 sec)
# I0709 02:00:54.295744 139621405767552 basic_session_run_hooks.py:260] lr = 0.00025584624 (6.044 sec)
# I0709 02:01:00.259471 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7488
# I0709 02:01:00.262056 139621405767552 basic_session_run_hooks.py:260] loss = 0.5406941, step = 4000 (5.969 sec)
# I0709 02:01:00.264717 139621405767552 basic_session_run_hooks.py:260] lr = 0.00025480395 (5.969 sec)
# I0709 02:01:06.230393 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7478
# I0709 02:01:06.232351 139621405767552 basic_session_run_hooks.py:260] loss = 0.5677341, step = 4100 (5.970 sec)
# I0709 02:01:06.235454 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002537659 (5.971 sec)
# I0709 02:01:12.187574 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7865
# I0709 02:01:12.191107 139621405767552 basic_session_run_hooks.py:260] loss = 0.55764365, step = 4200 (5.959 sec)
# I0709 02:01:12.193123 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002527321 (5.958 sec)
# I0709 02:01:18.128234 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.8331
# I0709 02:01:18.134887 139621405767552 basic_session_run_hooks.py:260] loss = 0.5697746, step = 4300 (5.944 sec)
# I0709 02:01:18.140058 139621405767552 basic_session_run_hooks.py:260] lr = 0.0
139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4503
# I0709 02:02:52.149454 139621405767552 basic_session_run_hooks.py:260] loss = 0.55797917, step = 5500 (6.080 sec)
# I0709 02:02:52.153387 139621405767552 basic_session_run_hooks.py:260] lr = 0.00023966962 (6.081 sec)
# I0709 02:02:58.148223 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6577
# I0709 02:02:58.150884 139621405767552 basic_session_run_hooks.py:260] loss = 0.54253155, step = 5600 (6.001 sec)
# I0709 02:02:58.153714 139621405767552 basic_session_run_hooks.py:260] lr = 0.00023869325 (6.001 sec)
# I0709 02:03:04.146011 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6728
# I0709 02:03:04.148146 139621405767552 basic_session_run_hooks.py:260] loss = 0.5440309, step = 5700 (5.997 sec)
# I0709 02:03:04.150225 139621405767552 basic_session_run_hooks.py:260] lr = 0.00023772083 (5.997 sec)
# I0709 02:03:10.126205 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7219
# I0709 02:03:10.132064 139621405767552 basic_session_run_hooks.py:260] loss = 0.5456837, step = 5800 (5.984 sec)
# I0709 02:03:10.133514 139621405767552 basic_session_run_hooks.py:260] lr = 0.00023675238 (5.983 sec)
# I0709 02:03:16.107091 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7199
# I0709 02:03:16.112111 139621405767552 basic_session_run_hooks.py:260] loss = 0.5497107, step = 5900 (5.980 sec)
# I0709 02:03:16.113955 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002357879 (5.980 sec)
# I0709 02:03:22.108125 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6638
# I0709 02:03:22.110809 139621405767552 basic_session_run_hooks.py:260] loss = 0.5551465, step = 6000 (5.999 sec)
# I0709 02:03:22.114281 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002348273 (6.000 sec)
# I0709 02:03:28.113019 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6531
# I0709 02:03:28.114878 139621405767552 basic_session_run_hooks.py:260] loss = 0.5611291, step = 6100 (6.004 sec)
# I0709 02:03:28.118502 139621405767552 basic_session_run_hooks.py:260] lr = 0.00023387067 (6.004 sec)
# I0709 02:03:34.183239 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4739
# I0709 02:03:34.187788 139621405767552 basic_session_run_hooks.py:260] loss = 0.5487413, step = 6200 (6.073 sec)
# I0709 02:03:34.191679 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002329179 (6.073 sec)
# I0709 02:03:40.216592 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5746
# I0709 02:03:40.222363 139621405767552 basic_session_run_hooks.py:260] loss = 0.56596065, step = 6300 (6.035 sec)
# I0709 02:03:40.224243 139621405767552 basic_session_run_hooks.py:260] lr = 0.000231969 (6.033 sec)
# I0709 02:03:46.208801 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6883
# I0709 02:03:46.213752 139621405767552 basic_session_run_hooks.py:260] loss = 0.5384862, step = 6400 (5.991 sec)
# I0709 02:03:46.215606 139621405767552 basic_session_run_hooks.py:260] lr = 0.00023102401 (5.991 sec)
# I0709 02:03:52.189768 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7197
# I0709 02:03:52.193791 139621405767552 basic_session_run_hooks.py:260] loss = 0.5561179, step = 6500 (5.980 sec)
# I0709 02:03:52.196027 139621405767552 basic_session_run_hooks.py:260] lr = 0.00023008283 (5.980 sec)
# I0709 02:03:58.161665 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7451
# I0709 02:03:58.163662 139621405767552 basic_session_run_hooks.py:260] loss = 0.5405821, step = 6600 (5.970 sec)
# I0709 02:03:58.165932 139621405767552 basic_session_run_hooks.py:260] lr = 0.00022914549 (5.970 sec)
# I0709 02:04:04.148092 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7045
# I0709 02:04:04.153228 139621405767552 basic_session_run_hooks.py:260] loss = 0.56069994, step = 6700 (5.990 sec)
# I0709 02:04:04.154878 139621405767552 basic_session_run_hooks.py:260] lr = 0.000228212 (5.989 sec)
# I0709 02:04:10.121408 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7411
# I0709 02:04:10.123946 139621405767552 basic_session_run_hooks.py:260] loss = 0.57288367, step = 6800 (5.971 sec)
# I0709 02:04:10.128911 139621405767552 basic_session_run_hooks.py:260] lr = 0.00022728226 (5.974 sec)
# I0709 02:04:16.101313 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.
139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6678
# I0709 02:05:43.635776 139621405767552 basic_session_run_hooks.py:260] loss = 0.54946816, step = 8000 (5.998 sec)
# I0709 02:05:43.639940 139621405767552 basic_session_run_hooks.py:260] lr = 0.00021641685 (6.000 sec)
# I0709 02:05:49.603968 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7485
# I0709 02:05:49.609204 139621405767552 basic_session_run_hooks.py:260] loss = 0.5286272, step = 8100 (5.973 sec)
# I0709 02:05:49.610780 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002155352 (5.971 sec)
# I0709 02:05:55.541788 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.8412
# I0709 02:05:55.543686 139621405767552 basic_session_run_hooks.py:260] loss = 0.56694764, step = 8200 (5.934 sec)
# I0709 02:05:55.547044 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002146571 (5.936 sec)
# Reading ../data/train.txt
# I0709 02:06:01.547131 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6518
# I0709 02:06:01.551222 139621405767552 basic_session_run_hooks.py:260] loss = 0.5160173, step = 8300 (6.008 sec)
# I0709 02:06:01.553308 139621405767552 basic_session_run_hooks.py:260] lr = 0.00021378264 (6.006 sec)
# I0709 02:06:07.518941 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7453
# I0709 02:06:07.523035 139621405767552 basic_session_run_hooks.py:260] loss = 0.53051466, step = 8400 (5.972 sec)
# I0709 02:06:07.525123 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002129117 (5.972 sec)
# I0709 02:06:13.568800 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5293
# I0709 02:06:13.571822 139621405767552 basic_session_run_hooks.py:260] loss = 0.53978395, step = 8500 (6.049 sec)
# I0709 02:06:13.575316 139621405767552 basic_session_run_hooks.py:260] lr = 0.00021204431 (6.050 sec)
# I0709 02:06:19.579889 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6359
# I0709 02:06:19.582771 139621405767552 basic_session_run_hooks.py:260] loss = 0.5397296, step = 8600 (6.011 sec)
# I0709 02:06:19.584017 139621405767552 basic_session_run_hooks.py:260] lr = 0.0002111805 (6.009 sec)
# I0709 02:06:25.591456 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6346
# I0709 02:06:25.593891 139621405767552 basic_session_run_hooks.py:260] loss = 0.5518324, step = 8700 (6.011 sec)
# I0709 02:06:25.597986 139621405767552 basic_session_run_hooks.py:260] lr = 0.00021032016 (6.014 sec)
# I0709 02:06:31.594335 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6588
# I0709 02:06:31.599668 139621405767552 basic_session_run_hooks.py:260] loss = 0.53714836, step = 8800 (6.006 sec)
# I0709 02:06:31.601767 139621405767552 basic_session_run_hooks.py:260] lr = 0.00020946334 (6.004 sec)
# I0709 02:06:37.649319 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5152
# I0709 02:06:37.651904 139621405767552 basic_session_run_hooks.py:260] loss = 0.5421218, step = 8900 (6.052 sec)
# I0709 02:06:37.656047 139621405767552 basic_session_run_hooks.py:260] lr = 0.00020861001 (6.054 sec)
# I0709 02:06:43.633638 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7104
# I0709 02:06:43.637875 139621405767552 basic_session_run_hooks.py:260] loss = 0.55136895, step = 9000 (5.986 sec)
# I0709 02:06:43.640522 139621405767552 basic_session_run_hooks.py:260] lr = 0.00020776017 (5.984 sec)
# I0709 02:06:49.613260 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7234
# I0709 02:06:49.615245 139621405767552 basic_session_run_hooks.py:260] loss = 0.5699175, step = 9100 (5.977 sec)
# I0709 02:06:49.619312 139621405767552 basic_session_run_hooks.py:260] lr = 0.00020691377 (5.979 sec)
# I0709 02:06:55.609969 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6758
# I0709 02:06:55.615731 139621405767552 basic_session_run_hooks.py:260] loss = 0.5407314, step = 9200 (6.000 sec)
# I0709 02:06:55.617425 139621405767552 basic_session_run_hooks.py:260] lr = 0.00020607082 (5.998 sec)
# I0709 02:07:01.619370 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6406
# I0709 02:07:01.624851 139621405767552 basic_session_run_hooks.py:260] loss = 0.5443659, step = 9300 (6.009 sec)
# I0709 02:07:01.626118 139621405767552 basic_session_run_hooks.py:260] lr = 0.00
139621405767552 basic_session_run_hooks.py:260] lr = 0.00019542004 (6.006 sec)
# I0709 02:08:41.596449 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6623
# I0709 02:08:41.600822 139621405767552 basic_session_run_hooks.py:260] loss = 0.5351507, step = 10600 (6.004 sec)
# I0709 02:08:41.602969 139621405767552 basic_session_run_hooks.py:260] lr = 0.00019462392 (6.003 sec)
# I0709 02:08:47.604202 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6452
# I0709 02:08:47.608254 139621405767552 basic_session_run_hooks.py:260] loss = 0.5388597, step = 10700 (6.007 sec)
# I0709 02:08:47.610636 139621405767552 basic_session_run_hooks.py:260] lr = 0.00019383106 (6.008 sec)
# I0709 02:08:53.705199 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.3909
# I0709 02:08:53.710950 139621405767552 basic_session_run_hooks.py:260] loss = 0.56545234, step = 10800 (6.103 sec)
# I0709 02:08:53.712798 139621405767552 basic_session_run_hooks.py:260] lr = 0.00019304141 (6.102 sec)
# I0709 02:08:59.708262 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6581
# I0709 02:08:59.710857 139621405767552 basic_session_run_hooks.py:260] loss = 0.5470368, step = 10900 (6.000 sec)
# I0709 02:08:59.712423 139621405767552 basic_session_run_hooks.py:260] lr = 0.00019225497 (6.000 sec)
# I0709 02:09:05.722747 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6265
# I0709 02:09:05.724869 139621405767552 basic_session_run_hooks.py:260] loss = 0.5468542, step = 11000 (6.014 sec)
# I0709 02:09:05.729248 139621405767552 basic_session_run_hooks.py:260] lr = 0.00019147176 (6.017 sec)
# I0709 02:09:11.739315 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6208
# I0709 02:09:11.742763 139621405767552 basic_session_run_hooks.py:260] loss = 0.5283701, step = 11100 (6.018 sec)
# I0709 02:09:11.746587 139621405767552 basic_session_run_hooks.py:260] lr = 0.00019069173 (6.017 sec)
# I0709 02:09:17.751336 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6334
# I0709 02:09:17.755372 139621405767552 basic_session_run_hooks.py:260] loss = 0.56390697, step = 11200 (6.013 sec)
# I0709 02:09:17.758246 139621405767552 basic_session_run_hooks.py:260] lr = 0.00018991488 (6.012 sec)
# I0709 02:09:23.735770 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.71
# I0709 02:09:23.740139 139621405767552 basic_session_run_hooks.py:260] loss = 0.5363313, step = 11300 (5.985 sec)
# I0709 02:09:23.742099 139621405767552 basic_session_run_hooks.py:260] lr = 0.00018914117 (5.984 sec)
# I0709 02:09:29.718899 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.7136
# I0709 02:09:29.723208 139621405767552 basic_session_run_hooks.py:260] loss = 0.5692455, step = 11400 (5.983 sec)
# I0709 02:09:29.724826 139621405767552 basic_session_run_hooks.py:260] lr = 0.00018837064 (5.983 sec)
# I0709 02:09:35.864310 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.2723
# I0709 02:09:35.868358 139621405767552 basic_session_run_hooks.py:260] loss = 0.55708957, step = 11500 (6.144 sec)
# ...
# I0709 02:54:41.718772 139621405767552 basic_session_run_hooks.py:260] loss = 0.5420022, step = 50000 (6.066 sec)
# I0709 02:54:41.720551 139621405767552 basic_session_run_hooks.py:260] lr = 3.896569e-05 (6.067 sec)
# I0709 02:54:47.798933 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.433
# I0709 02:54:47.802798 139621405767552 basic_session_run_hooks.py:260] loss = 0.50861865, step = 50100 (6.084 sec)
# I0709 02:54:47.804798 139621405767552 basic_session_run_hooks.py:260] lr = 3.880695e-05 (6.084 sec)
# I0709 02:54:53.844164 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.542
# I0709 02:54:53.848870 139621405767552 basic_session_run_hooks.py:260] loss = 0.49570584, step = 50200 (6.046 sec)
# I0709 02:54:53.850393 139621405767552 basic_session_run_hooks.py:260] lr = 3.8648857e-05 (6.046 sec)
# I0709 02:54:59.921834 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4536
# I0709 02:54:59.926553 139621405767552 basic_session_run_hooks.py:260] loss = 0.50551176, step = 50300 (6.078 sec)
# I0709 02:54:59.927820 139621405767552 basic_session_run_hooks.py:260] lr = 3.8491406e-05 (6.077 sec)
# I0709 02:55:05.960965 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5588
# I0709 02:55:05.966111 139621405767552 basic_session_run_hooks.py:260] loss = 0.5154787, step = 50400 (6.040 sec)
# I0709 02:55:05.967339 139621405767552 basic_session_run_hooks.py:260] lr = 3.8334598e-05 (6.040 sec)
# Reading ../data/train.txt
# I0709 02:55:12.009205 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5336
# I0709 02:55:12.014016 139621405767552 basic_session_run_hooks.py:260] loss = 0.5331649, step = 50500 (6.048 sec)
# I0709 02:55:12.015206 139621405767552 basic_session_run_hooks.py:260] lr = 3.8178423e-05 (6.048 sec)
# I0709 02:55:18.527571 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 15.3413
# I0709 02:55:18.530077 139621405767552 basic_session_run_hooks.py:260] loss = 0.5121768, step = 50600 (6.516 sec)
# I0709 02:55:18.534659 139621405767552 basic_session_run_hooks.py:260] lr = 3.802289e-05 (6.519 sec)
# I0709 02:55:24.591034 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4922
# I0709 02:55:24.593794 139621405767552 basic_session_run_hooks.py:260] loss = 0.5408025, step = 50700 (6.064 sec)
# I0709 02:55:24.598619 139621405767552 basic_session_run_hooks.py:260] lr = 3.786799e-05 (6.064 sec)
# I0709 02:55:30.630347 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5582
# I0709 02:55:30.632915 139621405767552 basic_session_run_hooks.py:260] loss = 0.5368419, step = 50800 (6.039 sec)
# I0709 02:55:30.635417 139621405767552 basic_session_run_hooks.py:260] lr = 3.771372e-05 (6.037 sec)
# I0709 02:55:36.674174 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5458
# I0709 02:55:36.676784 139621405767552 basic_session_run_hooks.py:260] loss = 0.5088283, step = 50900 (6.044 sec)
# I0709 02:55:36.681530 139621405767552 basic_session_run_hooks.py:260] lr = 3.7560083e-05 (6.046 sec)
# I0709 02:55:42.794386 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.3393
# I0709 02:55:42.801038 139621405767552 basic_session_run_hooks.py:260] loss = 0.54025394, step = 51000 (6.124 sec)
# I0709 02:55:42.802924 139621405767552 basic_session_run_hooks.py:260] lr = 3.7407062e-05 (6.121 sec)
# I0709 02:55:49.011634 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.0843
# I0709 02:55:49.017442 139621405767552 basic_session_run_hooks.py:260] loss = 0.51971245, step = 51100 (6.216 sec)
# I0709 02:55:49.019587 139621405767552 basic_session_run_hooks.py:260] lr = 3.7254675e-05 (6.217 sec)
# I0709 02:55:55.100978 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4221
# I0709 02:55:55.107731 139621405767552 basic_session_run_hooks.py:260] loss = 0.5203854, step = 51200 (6.090 sec)
# I0709 02:55:55.109231 139621405767552 basic_session_run_hooks.py:260] lr = 3.7102902e-05 (6.090 sec)
# I0709 02:56:01.163694 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4943
# I0709 02:56:01.165839 139621405767552 basic_session_run_hooks.py:260] loss = 0.50644624, step = 51300 (6.058 sec)
# I0709 02:56:01.170287 139621405767552 basic_session_run_hooks.py:260] lr = 3.6951744e-05 (6.061 sec)
# I0709 02:56:07.208308 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5437
# I0709 02:56:07.210928 139621405767552 basic_session_run_hooks.py:260] loss = 0.5331259, step = 51400 (6.045 sec)
# I0709 02:56:07.214687 139621405767552 basic_session_run_hooks.py:260] lr = 3.680121e-05 (6.044 sec)
# I0709 02:56:13.228648 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.6103
# I0709 02:56:13.230963 139621405767552 basic_session_run_hooks.py:260] loss = 0.53290504, step = 51500 (6.020 sec)
# I0709 02:56:13.235705 139621405767552 basic_session_run_hooks.py:260] lr = 3.6651283e-05 (6.021 sec)
# I0709 02:56:15.970758 139621405767552 basic_session_run_hooks.py:606] Saving checkpoints for 51546 into ../model/dnn/model.ckpt.
# I0709 02:56:16.282278 139621405767552 estimator.py:1145] Calling model_fn.
# I0709 02:56:16.693446 139621405767552 estimator.py:1147] Done calling model_fn.
# I0709 02:56:16.715855 139621405767552 evaluation.py:255] Starting evaluation at 2019-07-09T02:56:16Z
# I0709 02:56:16.827341 139621405767552 monitored_session.py:240] Graph was finalized.
# I0709 02:56:16.839907 139621405767552 saver.py:1280] Restoring parameters from ../model/dnn/model.ckpt-51546
# I0709 02:56:16.948668 139621405767552 session_manager.py:500] Running local_init_op.
# I0709 02:56:16.984541 139621405767552 session_manager.py:502] Done running local_init_op.
# Reading ../data/test.txt
# I0709 02:56:38.089678 139621405767552 evaluation.py:275] Finished evaluation at 2019-07-09-02:56:38
# I0709 02:56:38.090962 139621405767552 estimator.py:2039] Saving dict for global step 51546: global_step = 51546, loss = 0.54489946, mae = 0.6662765
# I0709 02:56:38.098142 139621405767552 estimator.py:2099] Saving 'checkpoint_path' summary for global step 51546: ../model/dnn/model.ckpt-51546
# I0709 02:56:41.465328 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 3.54149
# I0709 02:56:41.467923 139621405767552 basic_session_run_hooks.py:260] loss = 0.5328695, step = 51600 (28.237 sec)
# I0709 02:56:41.474031 139621405767552 basic_session_run_hooks.py:260] lr = 3.6501973e-05 (28.238 sec)
# I0709 02:56:47.550978 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4321
# I0709 02:56:47.558102 139621405767552 basic_session_run_hooks.py:260] loss = 0.52029943, step = 51700 (6.090 sec)
# I0709 02:56:47.559292 139621405767552 basic_session_run_hooks.py:260] lr = 3.635327e-05 (6.085 sec)
# I0709 02:56:53.615366 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4897
# I0709 02:56:53.617925 139621405767552 basic_session_run_hooks.py:260] loss = 0.5231755, step = 51800 (6.060 sec)
# I0709 02:56:53.621733 139621405767552 basic_session_run_hooks.py:260] lr = 3.620517e-05 (6.062 sec)
# I0709 02:56:59.691933 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4566
# I0709 02:56:59.694939 139621405767552 basic_session_run_hooks.py:260] loss = 0.53940594, step = 51900 (6.077 sec)
# I0709 02:56:59.699159 139621405767552 basic_session_run_hooks.py:260] lr = 3.6057674e-05 (6.077 sec)
# I0709 02:57:05.851539 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.2348
# I0709 02:57:05.857961 139621405767552 basic_session_run_hooks.py:260] loss = 0.5314974, step = 52000 (6.163 sec)
# I0709 02:57:05.859461 139621405767552 basic_session_run_hooks.py:260] lr = 3.591078e-05 (6.160 sec)
# I0709 02:57:11.986072 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.3011
# I0709 02:57:11.988242 139621405767552 basic_session_run_hooks.py:260] loss = 0.5329095, step = 52100 (6.130 sec)
# I0709 02:57:11.993741 139621405767552 basic_session_run_hooks.py:260] lr = 3.5764482e-05 (6.134 sec)
# I0709 02:57:18.094202 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.3716
# I0709 02:57:18.097780 139621405767552 basic_session_run_hooks.py:260] loss = 0.5362709, step = 52200 (6.110 sec)
# I0709 02:57:18.099195 139621405767552 basic_session_run_hooks.py:260] lr = 3.5618785e-05 (6.105 sec)
# I0709 02:57:24.152280 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5069
# I0709 02:57:24.154748 139621405767552 basic_session_run_hooks.py:260] loss = 0.52654254, step = 52300 (6.057 sec)
# I0709 02:57:24.157232 139621405767552 basic_session_run_hooks.py:260] lr = 3.5473677e-05 (6.058 sec)
# I0709 02:57:30.208217 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5127
# I0709 02:57:30.210811 139621405767552 basic_session_run_hooks.py:260] loss = 0.5413338, step = 52400 (6.056 sec)
# I0709 02:57:30.214167 139621405767552 basic_session_run_hooks.py:260] lr = 3.532916e-05 (6.057 sec)
# I0709 02:57:36.292779 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.435
# I0709 02:57:36.298092 139621405767552 basic_session_run_hooks.py:260] loss = 0.5245753, step = 52500 (6.087 sec)
# I0709 02:57:36.300338 139621405767552 basic_session_run_hooks.py:260] lr = 3.5185232e-05 (6.086 sec)
# I0709 02:57:42.357514 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4888
# I0709 02:57:42.364630 139621405767552 basic_session_run_hooks.py:260] loss = 0.5117682, step = 52600 (6.067 sec)
# I0709 02:57:42.366212 139621405767552 basic_session_run_hooks.py:260] lr = 3.5041892e-05 (6.066 sec)
# I0709 02:57:48.469364 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.3616
# I0709 02:57:48.475142 139621405767552 basic_session_run_hooks.py:260] loss = 0.52911526, step = 52700 (6.111 sec)
# I0709 02:57:48.477570 139621405767552 basic_session_run_hooks.py:260] lr = 3.4899138e-05 (6.111 sec)
# I0709 02:57:54.526039 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5107
# I0709 02:57:54.532752 139621405767552 basic_session_run_hooks.py:260] loss = 0.5550115, step = 52800 (6.058 sec)
# I0709 02:57:54.534355 139621405767552 basic_session_run_hooks.py:260] lr = 3.4756966e-05 (6.057 sec)
# I0709 02:58:00.554409 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5882
# I0709 02:58:00.556429 139621405767552 basic_session_run_hooks.py:260] loss = 0.5256791, step = 52900 (6.024 sec)
# I0709 02:58:00.561672 139621405767552 basic_session_run_hooks.py:260] lr = 3.461537e-05 (6.027 sec)
# I0709 02:58:06.620500 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4852
# I0709 02:58:06.622876 139621405767552 basic_session_run_hooks.py:260] loss = 0.54303837, step = 53000 (6.066 sec)
# I0709 02:58:06.626736 139621405767552 basic_session_run_hooks.py:260] lr = 3.4474346e-05 (6.065 sec)
# I0709 02:58:12.661628 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5532
# I0709 02:58:12.663867 139621405767552 basic_session_run_hooks.py:260] loss = 0.5337471, step = 53100 (6.041 sec)
# I0709 02:58:12.667423 139621405767552 basic_session_run_hooks.py:260] lr = 3.4333905e-05 (6.041 sec)
# I0709 02:58:18.735092 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.465
# I0709 02:58:18.740321 139621405767552 basic_session_run_hooks.py:260] loss = 0.5278878, step = 53200 (6.076 sec)
# I0709 02:58:18.742763 139621405767552 basic_session_run_hooks.py:260] lr = 3.4194036e-05 (6.075 sec)
# I0709 02:58:24.794748 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5026
# I0709 02:58:24.796867 139621405767552 basic_session_run_hooks.py:260] loss = 0.50696826, step = 53300 (6.057 sec)
# I0709 02:58:24.798019 139621405767552 basic_session_run_hooks.py:260] lr = 3.405473e-05 (6.055 sec)
# I0709 02:58:30.896390 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.389
# I0709 02:58:30.898772 139621405767552 basic_session_run_hooks.py:260] loss = 0.5253509, step = 53400 (6.102 sec)
# I0709 02:58:30.900034 139621405767552 basic_session_run_hooks.py:260] lr = 3.3915996e-05 (6.102 sec)
# I0709 02:58:36.982553 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4308
# I0709 02:58:36.985755 139621405767552 basic_session_run_hooks.py:260] loss = 0.509872, step = 53500 (6.087 sec)
# I0709 02:58:36.988122 139621405767552 basic_session_run_hooks.py:260] lr = 3.3777822e-05 (6.088 sec)
# I0709 02:58:43.052117 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.4756
# I0709 02:58:43.054920 139621405767552 basic_session_run_hooks.py:260] loss = 0.54782027, step = 53600 (6.069 sec)
# I0709 02:58:43.057276 139621405767552 basic_session_run_hooks.py:260] lr = 3.3640215e-05 (6.069 sec)
# I0709 02:58:49.118645 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.484
# I0709 02:58:49.124779 139621405767552 basic_session_run_hooks.py:260] loss = 0.5412403, step = 53700 (6.070 sec)
# I0709 02:58:49.126336 139621405767552 basic_session_run_hooks.py:260] lr = 3.3503176e-05 (6.069 sec)
# I0709 02:58:55.173620 139621405767552 basic_session_run_hooks.py:692] global_step/sec: 16.5153
# I0709 02:58:55.180468 139621405767552 basic_session_run_hooks.py:260] loss = 0.5373496, step = 53800 (6.056 sec)
# I0709 02:58:55.182388 139621405767552 basic_session_run_hooks.py:260] lr = 3.3366683e-05 (6.056 sec)
# I0709 02:59:00.485083 139621405767552 basic_session_run_hooks.py:606] Saving checkpoints for 53889 into ../model/dnn/model.ckpt.
# I0709 02:59:00.801281 139621405767552 estimator.py:1145] Calling model_fn.
# I0709 02:59:01.026079 139621405767552 estimator.py:1147] Done calling model_fn.
# I0709 02:59:01.049285 139621405767552 evaluation.py:255] Starting evaluation at 2019-07-09T02:59:01Z
# I0709 02:59:01.151919 139621405767552 monitored_session.py:240] Graph was finalized.
# I0709 02:59:01.165330 139621405767552 saver.py:1280] Restoring parameters from ../model/dnn/model.ckpt-53889
# I0709 02:59:01.277198 139621405767552 session_manager.py:500] Running local_init_op.
# I0709 02:59:01.313934 139621405767552 session_manager.py:502] Done running local_init_op.
# Reading ../data/test.txt
# I0709 02:59:22.371781 139621405767552 evaluation.py:275] Finished evaluation at 2019-07-09-02:59:22
# I0709 02:59:22.373052 139621405767552 estimator.py:2039] Saving dict for global step 53889: global_step = 53889, loss = 0.54498446, mae = 0.66572577
# I0709 02:59:22.380182 139621405767552 estimator.py:2099] Saving 'checkpoint_path' summary for global step 53889: ../model/dnn/model.ckpt-53889
# I0709 02:59:22.456585 139621405767552 early_stopping.py:415] No decrease in metric "mae" for 18744 steps, which is greater than or equal to max steps (16406) configured for early stopping.
# I0709 02:59:22.457662 139621405767552 early_stopping.py:485] Requesting early stopping at global step 53889
# I0709 02:59:22.495007 139621405767552 basic_session_run_hooks.py:606] Saving checkpoints for 53890 into ../model/dnn/model.ckpt.
# I0709 02:59:22.796017 139621405767552 estimator.py:1145] Calling model_fn.
# I0709 02:59:23.018811 139621405767552 estimator.py:1147] Done calling model_fn.
# I0709 02:59:23.041270 139621405767552 evaluation.py:255] Starting evaluation at 2019-07-09T02:59:23Z
# I0709 02:59:23.143836 139621405767552 monitored_session.py:240] Graph was finalized.
# I0709 02:59:23.158225 139621405767552 saver.py:1280] Restoring parameters from ../model/dnn/model.ckpt-53890
# I0709 02:59:23.275290 139621405767552 session_manager.py:500] Running local_init_op.
# I0709 02:59:23.311379 139621405767552 session_manager.py:502] Done running local_init_op.
# Reading ../data/test.txt
# I0709 02:59:44.820681 139621405767552 evaluation.py:275] Finished evaluation at 2019-07-09-02:59:44
# I0709 02:59:44.827504 139621405767552 estimator.py:2039] Saving dict for global step 53890: global_step = 53890, loss = 0.5449746, mae = 0.66575235
# I0709 02:59:44.829806 139621405767552 estimator.py:2099] Saving 'checkpoint_path' summary for global step 53890: ../model/dnn/model.ckpt-53890
# I0709 02:59:48.564234 139621405767552 estimator.py:368] Loss for final step: 0.55210155.
# ({'global_step': 53890, 'loss': 0.5449746, 'mae': 0.66575235}, [])
